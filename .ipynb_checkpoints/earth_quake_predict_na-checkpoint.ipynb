# %% [markdown]
# # Dữ liệu không loại bỏ các mẫu chứa trường có giá trị NA

# %%
import pandas as pd, seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %% [markdown]
# Dưới đây là các hàm phục vụ việc tiền xử lý dữ liệu như one-hot coding hoặc chia tập train - validation

# %%
# Function to one-hot coding using get_dummies() method
def one_hot(matrix, column):
    type_dummies = pd.get_dummies(matrix[column], prefix='type')
    matrix.drop([column], axis=1, inplace=True)
    matrix = pd.concat([matrix, type_dummies], axis=1)
    return matrix


# Function to split the training set and validation set
def split_data(x_data, y_data, test_size):
    x_train, x_test, y_train, y_test = train_test_split(x_data,
                                                        y_data,
                                                        test_size=test_size,
                                                        random_state=42)
    return x_train, x_test, y_train, y_test

# %%
# Read data
# Change data path on your computer
data_path = 'earthquakes.csv'
data = pd.read_csv(data_path)
# Print the data information
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1137 entries, 0 to 1136
# Data columns (total 43 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               1137 non-null   object
#  1   magnitude        1137 non-null   float64
#  2   type             1137 non-null   object
#  3   title            1137 non-null   object
#  4   date             1137 non-null   object
#  5   time             1137 non-null   int64
#  6   updated          1137 non-null   int64
#  7   url              1137 non-null   object
#  8   detailUrl        1137 non-null   object
#  9   felt             1137 non-null   int64
#  10  cdi              1137 non-null   int64
#  11  mmi              1137 non-null   int64
#  12  alert            764 non-null    object
#  13  status           1137 non-null   object
#  14  tsunami          1137 non-null   int64
#  15  sig              1137 non-null   int64
#  16  net              1137 non-null   object
#  17  code             1137 non-null   object
#  18  ids              1137 non-null   object
#  19  sources          1137 non-null   object
#  20  types            1137 non-null   object
#  21  nst              1137 non-null   int64
#  22  dmin             1137 non-null   float64
#  23  rms              1137 non-null   float64
#  24  gap              1137 non-null   float64
#  25  magType          1137 non-null   object
#  26  geometryType     1137 non-null   object
#  27  depth            1137 non-null   float64
#  28  latitude         1137 non-null   float64
#  29  longitude        1137 non-null   float64
#  30  place            1137 non-null   object
#  31  distanceKM       1137 non-null   int64
#  32  placeOnly        1137 non-null   object
#  33  location         1137 non-null   object
#  34  continent        867 non-null    object
#  35  country          799 non-null    object
#  36  subnational      716 non-null    object
#  37  city             674 non-null    object
#  38  locality         1137 non-null   object
#  39  postcode         197 non-null    float64
#  40  what3words       1137 non-null   object
#  41  timezone         1137 non-null   int64
#  42  locationDetails  1137 non-null   object
# dtypes: float64(8), int64(10), object(25)
# memory usage: 382.1+ KB

# %%
# Print the data description
data.describe()
# Out:
#          magnitude          time       updated           felt          cdi  \
# count  1137.000000  1.137000e+03  1.137000e+03    1137.000000  1137.000000
# mean      4.856675  1.712109e+12  1.716593e+12     414.408091     2.925242
# std       1.047840  1.143033e+10  9.671955e+09    5746.971362     2.562707
# min       3.000000  1.687542e+12  1.693083e+12       0.000000     0.000000
# 25%       3.800000  1.701663e+12  1.707609e+12       0.000000     0.000000
# 50%       5.300000  1.713810e+12  1.719958e+12       2.000000     3.000000
# 75%       5.600000  1.722885e+12  1.725384e+12      24.000000     5.000000
# max       7.600000  1.726661e+12  1.726672e+12  183786.000000     9.000000
#
#                mmi      tsunami          sig          nst         dmin  \
# count  1137.000000  1137.000000  1137.000000  1137.000000  1137.000000
# mean      4.320141     0.059807   432.698329   115.094107     1.342604
# std       1.453949     0.237232   256.177844    91.877870     1.704364
# min       1.000000     0.000000   138.000000     0.000000     0.000000
# 25%       4.000000     0.000000   234.000000    37.000000     0.100000
# 50%       4.000000     0.000000   449.000000   102.000000     0.680000
# 75%       5.000000     0.000000   518.000000   157.000000     2.061000
# max       9.000000     1.000000  2419.000000   619.000000    12.457000
#
#                rms          gap        depth     latitude    longitude  \
# count  1137.000000  1137.000000  1137.000000  1137.000000  1137.000000
# mean      0.585974    55.055286    41.287300    27.308909    -3.930635
# std       0.308556    37.609237    87.866489    20.133139   118.043697
# min       0.000000     0.000000    -0.250000   -43.706400  -179.807000
# 25%       0.300000    30.000000     7.550000    24.195400  -104.452000
# 50%       0.630000    49.000000    10.000000    31.667700   -68.682000
# 75%       0.780000    68.000000    34.723000    37.497600   126.628000
# max       2.520000   256.000000   639.503000    68.176100   179.972000
#
#         distanceKM      postcode     timezone
# count  1137.000000    197.000000  1137.000000
# mean     52.289358  83086.131980    21.741425
# std      56.027469  12812.555204   440.864430
# min       0.000000   8833.000000  -720.000000
# 25%      15.000000  79331.000000  -360.000000
# 50%      37.000000  79772.000000  -180.000000
# 75%      61.000000  92530.000000   480.000000
# max     298.000000  99827.000000   780.000000

# %% [markdown]
# ## Tiền xử lý dữ liệu

# %%
# Remove some features that aren't important for classify / clustering the alert of the earthquake
# Feature 'date' is already converted to float type in the original dataset 
data.drop(['id', 'date', 'title', 'url', 'detailUrl', 'ids', 'sources',
           'types', 'net', 'code', 'geometryType', 'status',
           'postcode', 'what3words', 'locationDetails'], axis=1, inplace=True)
# Replace Null value of column 'alert' to unknown 
data.fillna({'alert': 'unknown'}, inplace=True)

# %%
# NA-value columns will be filled by 'unknown' value
na_column = data.columns[data.isna().any()].tolist()

for column in na_column:
    data.fillna({column: 'unknown'}, inplace=True)

# String-value columns will be one-hot coding
string_columns = data.select_dtypes(include=['object']).columns.tolist()
string_columns.remove('alert')

for column in string_columns:
    one_hot(data, column)

x_data = data.drop(['alert'], axis=1)
x_data = StandardScaler().fit_transform(x_data)
y_data = data['alert']

data.head()
# Out:
#    magnitude           time        updated  felt  cdi  mmi    alert  tsunami  \
# 0        4.8  1726534182289  1726583895255  1893    6    5    green        0
# 1        5.1  1726534182183  1726672002991  2042    6    5    green        0
# 2        3.7  1726485728190  1726637414586  1580    4    4  unknown        0
# 3        3.9  1726333266539  1726584426218     5    3    4    green        0
# 4        4.1  1726333266382  1726334616179     4    3    4    green        0
#
#     sig  nst     dmin   rms   gap    depth  latitude  longitude  distanceKM  \
# 0   994   37  0.28700  0.48  70.0   4.0440   32.3984   -102.044          33
# 1  1040   24  0.00000  0.10  38.0   6.1279   32.4140   -102.057          34
# 2   591  135  0.03294  0.28  99.0  10.9000   34.0678   -118.807           6
# 3   236   38  0.00000  0.10  65.0   6.2024   31.6470   -104.450          58
# 4   260   28  0.04300  0.26  67.0   8.8140   31.6323   -104.473          60
#
#    timezone
# 0      -300
# 1      -300
# 2      -420
# 3      -300
# 4      -300

# %% [markdown]
# ## Giảm chiều dữ liệu
# ### Phương pháp PCA

# %%
# Dimensionality reduction
# Using PCA method
pca = PCA(n_components=2, random_state=42)
x_data_pca = pca.fit_transform(x_data)

# %% [markdown]
# **Trực quan hóa dữ liệu**

# %%
# Data visualization (2d scatter plot) 
pc1 = x_data_pca[:, 0]
pc2 = x_data_pca[:, 1]
sns.scatterplot(x=pc1, y=pc2, hue=y_data)
# Creat scatter plot
plot = sns.scatterplot(x=pc1, y=pc2, hue=y_data)
# Rename axis
plot.set(xlabel="First Principal Component", ylabel="Second Principal Component")
plt.show()

# %% [markdown]
# ### Phương pháp LDA

# %%
# Dimensionality reduction
# Using LDA method
lda = LDA(n_components=2)
x_data_lda = lda.fit_transform(x_data, y_data)

# %%
# Data visualization (2d scatter plot) 
pc1 = x_data_lda[:, 0]
pc2 = x_data_lda[:, 1]
# Creat scatter plot
custom_palette = {'red': "red", 'yellow': "yellow", 'green': "green", 'unknown': "purple", 'orange': "orange"}
plot_lda = sns.scatterplot(x=pc1, y=pc2, hue=y_data, palette=custom_palette)
# Rename axis
plot_lda.set(xlabel="First Principal Component", ylabel="Second Principal Component")
plt.show()

# %% [markdown]
# **Đánh giá các thành phần chính theo tham số thống kê** và **Xác định lượng thông tin được bảo tồn theo phương sai giải thích**

# %%
# Print the explained variance after reduce dimension of the data 
print(f'Explained variance: {np.cumsum(pca.explained_variance_)}')
# Print the statistic values of Principal Component
pd.DataFrame(data=x_data_pca,
             columns=['First Principal Component',
                      'Second Principal Component']).describe()
# Out:
# Explained variance: [5.79038133 8.00272516]
#        First Principal Component  Second Principal Component
# count               1.137000e+03                1.137000e+03
# mean               -1.249855e-16               -5.624349e-17
# std                 2.406321e+00                1.487395e+00
# min                -4.247917e+00               -4.320333e+00
# 25%                -2.592263e+00               -9.703910e-01
# 50%                 8.249570e-01               -8.439121e-02
# 75%                 2.114002e+00                7.183299e-01
# max                 5.793213e+00                9.984375e+00

# %% [markdown]
# **Thực hiện hiển thị trực quan đối với dữ liệu theo từng cặp 02 thành phần chính**

# %%
pca_pair = PCA(n_components=6)
X_pca = pca_pair.fit_transform(x_data)
df_pca = pd.DataFrame(X_pca, columns=[f'PC{i + 1}' for i in range(6)])
df_pca['target'] = y_data
plt.figure(figsize=(15, 10))
sns.pairplot(df_pca, hue='target', diag_kind='kde',
             plot_kws={'alpha': 0.6, 's': 50, 'edgecolor': 'k'},
             vars=[f'PC{i + 1}' for i in range(6)])  # Sử dụng 4 thành phần chính
plt.suptitle("Scatter Plots of Pairwise Principal Components", y=1.02)
plt.show()

# %% [markdown]
# ### Test size = 0.2

# %% [markdown]
# MÔ HÌNH HỒI QUY SOFTMAX VỚI DỮ LIỆU GỐC

# %%
# from sklearn.linear_model import LogisticRegression
# from sklearn.metrics import accuracy_score, precision_score, recall_score
# import time
# 
# def softmax_original_data(x_data, y_data):
#     x_train, x_test, y_train, y_test = split_data(x_data, y_data, 0.2)
#     
#     # Multinomial Logistic Regression
#     start_time_train = time.time()
#     lorg = LogisticRegression(max_iter=5000, solver='saga')
#     lorg.fit(x_train, y_train)
#     end_time_train = time.time()
#     time_training = end_time_train - start_time_train
#     print("Time training original data with softmax model: ", time_training)
#     
#     # Prediction
#     start_time_predict = time.time()
#     y_pred = lorg.predict(x_test)
#     end_time_predict = time.time()
#     time_predict = end_time_predict - start_time_predict
#     print("Time predict original data with softmax model: ", time_predict)
#     
#     # Accuracy
#     accuracy = accuracy_score(y_test, y_pred)
#     print("Accuracy of original data: ", accuracy)
#     # Precision
#     precision = precision_score(y_test, y_pred, average='macro', zero_division=1)
#     print("Precision of original data: ", precision)
#     # Recall
#     recall = recall_score(y_test, y_pred, average='macro')
#     print("Recall of original data: ", recall)
#

# %% [markdown]
# MÔ HÌNH HỒI QUY SOFTMAX VỚI DỮ LIỆU ĐÃ GIẢM CHIỀU PCA

# %%
# def softmax_pca_data(x_data_pca, y_data):
#     x_pca_train, x_pca_test, y_pca_train, y_pca_test = split_data(x_data_pca, y_data, 0.2)
#     
#     # Multinomial Logistic Regression
#     start_time_train = time.time()
#     lorg = LogisticRegression(max_iter=5000, solver='saga')
#     lorg.fit(x_pca_train, y_pca_train)
#     end_time_train = time.time()
#     time_training = end_time_train - start_time_train
#     print("\nTime training PCA data with softmax model: ", time_training)
#     
#     # Prediction
#     start_time_predict = time.time()
#     y_pred_pca = lorg.predict(x_pca_test)
#     end_time_predict = time.time()
#     time_predict = end_time_predict - start_time_predict
#     print("Time predict PCA data with softmax model: ", time_predict)
#     
#     # Accuracy
#     accuracy = accuracy_score(y_pca_test, y_pred_pca)
#     print("Accuracy after PCA: ", accuracy)
#     # Precision
#     precision = precision_score(y_pca_test, y_pred_pca, average='macro', zero_division=1)
#     print("Precision after PCA: ", precision)
#     # Recall
#     recall = recall_score(y_pca_test, y_pred_pca, average='macro')
#     print("Recall after PCA: ", recall)
#

# %% [markdown]
# MÔ HÌNH HỒI QUY SOFTMAX SAU KHI GIẢM CHIỀU LDA

# %%
# def softmax_lda_data(x_data_lda, y_data):
#     x_lda_train, x_lda_test, y_lda_train, y_lda_test = split_data(x_data_lda, y_data, 0.2)
#     
#     # Multinomial Logistic Regression
#     start_time_train = time.time()
#     lorg = LogisticRegression(max_iter=5000, solver='saga')
#     lorg.fit(x_lda_train, y_lda_train)
#     end_time_train = time.time()
#     time_training = end_time_train - start_time_train
#     print("\nTime training LDA data with softmax model: ", time_training)
#     
#     # Prediction
#     start_time_predict = time.time()
#     y_pred_pca = lorg.predict(x_lda_test)
#     end_time_predict = time.time()
#     time_predict = end_time_predict - start_time_predict
#     print("Time predict LDA data with softmax model: ", time_predict)
#     
#     # Accuracy
#     accuracy = accuracy_score(y_lda_test, y_pred_pca)
#     print("Accuracy after LDA: ", accuracy)
#     # Precision
#     precision = precision_score(y_lda_test, y_pred_pca, average='macro', zero_division=1)
#     print("Precision after LDA: ", precision)
#     # Recall
#     recall = recall_score(y_lda_test, y_pred_pca, average='macro')
#     print("Recall after LDA: ", recall)
#

# %%
# softmax_original_data(x_data, y_data)
# softmax_pca_data(x_data_pca, y_data)
# softmax_lda_data(x_data_lda, y_data)
# Out:
# Time training original data with softmax model:  0.37987780570983887
# Time predict original data with softmax model:  0.0009996891021728516
# Accuracy of original data:  0.956140350877193
# Precision of original data:  0.98187414500684
# Recall of original data:  0.9325355978727053
#
# Time training PCA data with softmax model:  0.17603778839111328
# Time predict PCA data with softmax model:  0.0
# Accuracy after PCA:  0.9122807017543859
# Precision after PCA:  0.8199403239556693
# Recall after PCA:  0.621161434208269
#
# Time training LDA data with softmax model:  0.09146761894226074
# Time predict LDA data with softmax model:  0.0010004043579101562
# Accuracy after LDA:  0.9385964912280702
# Precision after LDA:  0.878994032395567
# Recall after LDA:  0.6802367472979928

# %% [markdown]
# ### Test size = 0.3

# %% [markdown]
# DỮ LIỆU GỐC

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score
import time

def softmax_original_data(x_data, y_data, test_size):
    x_train, x_test, y_train, y_test = split_data(x_data, y_data, test_size)
    
    # Multinomial Logistic Regression
    start_time_train = time.time()
    lorg = LogisticRegression(max_iter=5000, solver='saga')
    lorg.fit(x_train, y_train)
    end_time_train = time.time()
    time_training = end_time_train - start_time_train
    print("Time training original data with softmax model: ", time_training)
    
    # Prediction
    start_time_predict = time.time()
    y_pred = lorg.predict(x_test)
    end_time_predict = time.time()
    time_predict = end_time_predict - start_time_predict
    print("Time predict original data with softmax model: ", time_predict)
    
    # Accuracy
    accuracy = accuracy_score(y_test, y_pred)
    print("Accuracy of original data: ", accuracy)
    # Precision
    precision = precision_score(y_test, y_pred, average='macro', zero_division=1)
    print("Precision of original data: ", precision)
    # Recall
    recall = recall_score(y_test, y_pred, average='macro')
    print("Recall of original data: ", recall)

# %% [markdown]
# DỮ LIỆU GIẢM CHIỀU PCA

# %%
def softmax_pca_data(x_data_pca, y_data, test_size):
    x_pca_train, x_pca_test, y_pca_train, y_pca_test = split_data(x_data_pca, y_data, test_size)
    
    # Multinomial Logistic Regression
    start_time_train = time.time()
    lorg = LogisticRegression(max_iter=5000, solver='saga')
    lorg.fit(x_pca_train, y_pca_train)
    end_time_train = time.time()
    time_training = end_time_train - start_time_train
    print("\nTime training PCA data with softmax model: ", time_training)
    
    # Prediction
    start_time_predict = time.time()
    y_pred_pca = lorg.predict(x_pca_test)
    end_time_predict = time.time()
    time_predict = end_time_predict - start_time_predict
    print("Time predict PCA data with softmax model: ", time_predict)
    
    # Accuracy
    accuracy = accuracy_score(y_pca_test, y_pred_pca)
    print("Accuracy after PCA: ", accuracy)
    # Precision
    precision = precision_score(y_pca_test, y_pred_pca, average='macro', zero_division=1)
    print("Precision after PCA: ", precision)
    # Recall
    recall = recall_score(y_pca_test, y_pred_pca, average='macro')
    print("Recall after PCA: ", recall)

# %% [markdown]
# DỮ LIỆU GIẢM CHIỀU LDA

# %%
def softmax_lda_data(x_data_lda, y_data, test_size):
    x_lda_train, x_lda_test, y_lda_train, y_lda_test = split_data(x_data_lda, y_data, test_size)
    
    # Multinomial Logistic Regression
    start_time_train = time.time()
    lorg = LogisticRegression(max_iter=5000, solver='saga')
    lorg.fit(x_lda_train, y_lda_train)
    end_time_train = time.time()
    time_training = end_time_train - start_time_train
    print("\nTime training LDA data with softmax model: ", time_training)
    
    # Prediction
    start_time_predict = time.time()
    y_pred_pca = lorg.predict(x_lda_test)
    end_time_predict = time.time()
    time_predict = end_time_predict - start_time_predict
    print("Time predict LDA data with softmax model: ", time_predict)
    
    # Accuracy
    accuracy = accuracy_score(y_lda_test, y_pred_pca)
    print("Accuracy after LDA: ", accuracy)
    # Precision
    precision = precision_score(y_lda_test, y_pred_pca, average='macro', zero_division=1)
    print("Precision after LDA: ", precision)
    # Recall
    recall = recall_score(y_lda_test, y_pred_pca, average='macro')
    print("Recall after LDA: ", recall)

# %%
# Test_size = 0.2
softmax_original_data(x_data, y_data, 0.2)
softmax_pca_data(x_data_pca, y_data, 0.2)
softmax_lda_data(x_data_lda, y_data, 0.2)

# Test_size = 0.3
softmax_original_data(x_data, y_data, 0.3)
softmax_pca_data(x_data_pca, y_data, 0.3)
softmax_lda_data(x_data_lda, y_data, 0.3)

# %% [markdown]
# ## Nhận xét
# 1. Thời gian huấn luyện và dự đoán
# - Dữ liệu gốc: Thời gian huấn luyện khoảng 0.38 giây và thời gian dự đoán 0.001 giây.
# - Dữ liệu sau PCA: Thời gian huấn luyện giảm còn 0.18 giây và thời gian dự đoán là 0 giây (nhanh hơn rõ rệt so với dữ liệu gốc).
# - Dữ liệu sau LDA: Thời gian huấn luyện giảm đáng kể, chỉ còn 0.09 giây và thời gian dự đoán gần như không đổi.
#
# Nhận xét: Cả hai phương pháp giảm chiều, đặc biệt là LDA, giúp giảm thời gian huấn luyện đáng kể. Điều này đặc biệt hữu ích khi làm việc với dữ liệu lớn hoặc yêu cầu xử lý nhanh.
#
# 2. Độ chính xác (Accuracy)
# - Dữ liệu gốc: Độ chính xác là 0.956 (95.61%).
# - Dữ liệu sau PCA: Độ chính xác giảm nhẹ còn 0.912 (91.22%).
# - Dữ liệu sau LDA: Độ chính xác đạt 0.939 (93.86%), gần với kết quả của dữ liệu gốc.
#
# Nhận xét: LDA duy trì độ chính xác tốt hơn PCA và gần hơn với kết quả của dữ liệu gốc. Điều này cho thấy LDA có thể giữ lại nhiều thông tin quan trọng trong dữ liệu, đồng thời giảm số chiều hiệu quả hơn trong trường hợp này.
#
# 3. Độ chính xác theo từng lớp (Precision)
# - Dữ liệu gốc: Precision là 0.982.
# - Dữ liệu sau PCA: Precision giảm xuống còn 0.820.
# - Dữ liệu sau LDA: Precision là 0.879, vẫn thấp hơn dữ liệu gốc nhưng cao hơn dữ liệu PCA.
#
# Nhận xét: LDA đạt precision tốt hơn so với PCA, gần hơn với kết quả của dữ liệu gốc, cho thấy LDA giữ lại khả năng phân biệt giữa các lớp tốt hơn trong bài toán này.
#
# 4. Độ phủ (Recall)
# - Dữ liệu gốc: Recall là 0.933.
# - Dữ liệu sau PCA: Recall giảm xuống còn 0.621.
# - Dữ liệu sau LDA: Recall là 0.680, cao hơn so với PCA nhưng thấp hơn dữ liệu gốc.
#
# Nhận xét: LDA cải thiện recall so với PCA nhưng vẫn chưa đạt được mức của dữ liệu gốc. Tuy nhiên, độ phủ của LDA vẫn khá tốt và có thể chấp nhận được nếu cần tối ưu hóa hiệu suất.
#
# 5. Đánh giá khả năng overfitting
# - Dữ liệu gốc: Với các chỉ số cao và cân bằng, mô hình không có dấu hiệu overfit.
# - Dữ liệu sau PCA: Sự giảm mạnh của recall, cùng với precision giảm, cho thấy PCA làm mất đi một số thông tin quan trọng, nhưng điều này cũng giúp giảm nguy cơ overfit.
# - Dữ liệu sau LDA: LDA đạt được sự cân bằng tốt hơn giữa các chỉ số và cũng không có dấu hiệu overfit. Việc giảm chiều bằng LDA đã duy trì phần lớn thông tin quan trọng mà không gây overfitting.

# %% [markdown]
# ## Kết luận
# - Nếu ưu tiên là tốc độ và không cần độ chính xác cao nhất, PCA là một lựa chọn hợp lý do giảm đáng kể thời gian huấn luyện và dự đoán.
# - Nếu cần duy trì độ chính xác và khả năng phân loại tốt cho từng lớp, LDA là phương pháp giảm chiều tối ưu hơn trong trường hợp này, vì nó giữ lại nhiều thông tin có giá trị hơn, dẫn đến hiệu suất cao hơn.
#
# Trong bối cảnh yêu cầu cả hiệu suất lẫn hiệu quả, LDA là lựa chọn tốt nhất, vì nó giúp giảm thời gian huấn luyện đáng kể mà vẫn duy trì độ chính xác, precision, và recall gần với dữ liệu gốc.
